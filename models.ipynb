# %%
from sqlmodel import create_engine, SQLModel, Session, select
from qlab import models

engine = create_engine("sqlite:///Q.tmix", echo=True)

# %%
SQLModel.metadata.create_all(engine)
# Out:
# 2025-10-18 15:45:12,865 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-18 15:45:12,867 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("config")
# 2025-10-18 15:45:12,868 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,872 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("cues")
# 2025-10-18 15:45:12,867 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("config")
# 2025-10-18 15:45:12,868 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,872 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("cues")
# 2025-10-18 15:45:12,873 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,876 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("profiles")
# 2025-10-18 15:45:12,876 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,877 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("positions")
# 2025-10-18 15:45:12,879 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,880 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("ensembles")
# 2025-10-18 15:45:12,882 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,883 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("actors")
# 2025-10-18 15:45:12,884 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,884 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("actorProfiles")
# 2025-10-18 15:45:12,885 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,886 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("actorGroups")
# 2025-10-18 15:45:12,887 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,887 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("snippetCache")
# 2025-10-18 15:45:12,888 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,888 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("fxCache")
# 2025-10-18 15:45:12,889 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,890 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("sceneCache")
# 2025-10-18 15:45:12,890 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-18 15:45:12,891 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    cue = models.Cue(name="Q2", number=10, point=2)
    session.add(cue)
    session.commit()
# Out:
# 2025-10-18 15:48:58,369 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-18 15:48:58,370 INFO sqlalchemy.engine.Engine INSERT INTO cues (number, point, name, "dca01Channels", "dca02Channels", "dca03Channels", "dca04Channels", "dca05Channels", "dca06Channels", "dca07Channels", "dca08Channels", "dca09Channels", "dca10Channels", "dca11Channels", "dca12Channels", "dca01Label", "dca02Label", "dca03Label", "dca04Label", "dca05Label", "dca06Label", "dca07Label", "dca08Label", "dca09Label", "dca10Label", "dca11Label", "dca12Label", "channelPositions", "channelProfiles", "fxMutes", "channelFX", snippets, "qLabCue", "channelLevels", scenes, colour, "scenePoints") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-10-18 15:48:58,371 INFO sqlalchemy.engine.Engine [cached since 225s ago] (10, 2, 'Q2', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 2025-10-18 15:48:58,372 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-18 15:48:58,370 INFO sqlalchemy.engine.Engine INSERT INTO cues (number, point, name, "dca01Channels", "dca02Channels", "dca03Channels", "dca04Channels", "dca05Channels", "dca06Channels", "dca07Channels", "dca08Channels", "dca09Channels", "dca10Channels", "dca11Channels", "dca12Channels", "dca01Label", "dca02Label", "dca03Label", "dca04Label", "dca05Label", "dca06Label", "dca07Label", "dca08Label", "dca09Label", "dca10Label", "dca11Label", "dca12Label", "channelPositions", "channelProfiles", "fxMutes", "channelFX", snippets, "qLabCue", "channelLevels", scenes, colour, "scenePoints") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-10-18 15:48:58,371 INFO sqlalchemy.engine.Engine [cached since 225s ago] (10, 2, 'Q2', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# 2025-10-18 15:48:58,372 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    clips = session.exec(select(models.Cue)).all()
    for clip in clips:
        print(clip)
